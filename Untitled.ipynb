# %%
import os
import matplotlib.pyplot as plt
import keras
import numpy as np
import pickle
import cv2
import random

# %%
DIRECTORY=r'D:\ML workshop\ImageClassifier\dogscats\dataset'
CATEGORIES=['cats','dogs']

# %%
IMG_SIZE=100
data=[]
for category in CATEGORIES:
    folder=os.path.join(DIRECTORY,category)
    label=CATEGORIES.index(category)
    for img in os.listdir(folder):
        img_path=os.path.join(folder,img)
        img_arr=cv2.imread(img_path)
        img_arr=cv2.resize(img_arr,(IMG_SIZE,IMG_SIZE))
        data.append([img_arr,label])

# %%
len(data)
# Out:
# 23000

# %%
random.shuffle(data)

# %%
X=[]
Y=[]

for features,label in data:
    X.append(features)
    Y.append(label)

# %%
X=np.array(X)
Y=np.array(Y)

# %%
X=X/225

# %%
X.shape
# Out:
# (23000, 100, 100, 3)

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense

# %%
model=Sequential()
model.add(Conv2D(64,(3,3),activation = 'relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),activation = 'relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(128,input_shape=X.shape[1:],activation='relu'))
model.add(Dense(2,activation = 'softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X,Y,epochs=5,validation_split=0.1)
# Out:
# Epoch 1/5
# 647/647 [==============================] - 1367s 2s/step - loss: 0.6295 - accuracy: 0.6374 - val_loss: 0.6172 - val_accuracy: 0.6804
# Epoch 2/5
# 647/647 [==============================] - 1394s 2s/step - loss: 0.4829 - accuracy: 0.7665 - val_loss: 0.4765 - val_accuracy: 0.7809
# Epoch 3/5
# 647/647 [==============================] - 1323s 2s/step - loss: 0.3910 - accuracy: 0.8204 - val_loss: 0.4559 - val_accuracy: 0.7917
# Epoch 4/5
# 647/647 [==============================] - 1299s 2s/step - loss: 0.2893 - accuracy: 0.8767 - val_loss: 0.4850 - val_accuracy: 0.7991
# Epoch 5/5
# 647/647 [==============================] - 1290s 2s/step - loss: 0.1551 - accuracy: 0.9394 - val_loss: 0.6084 - val_accuracy: 0.7917

# %%
test_image=cv2.imread('image.png')
show_img=test_image
test_image=cv2.resize(test_image,(100,100))
test_image=test_image.reshape(1,100,100,3)
result=model.predict(test_image)
if(result[0][0]==1):
    print("Image is of a cat")
else:
    print("Image is of a dog")
    show_img=cv2.cvtColor(show_img,cv2.COLOR_BGR2RGB)
plt.imshow(show_img)
# Out:
# Image is of a cat
